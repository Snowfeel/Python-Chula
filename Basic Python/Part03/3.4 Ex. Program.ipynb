# %% [markdown]
# # Ex. Program

# %%
from random import randint
play = True
point = 0
while play:
    user = input("Please Enter(Rock,Scissor,Paper): ")
    cpu = randint(1,3)
    if cpu == 1 and user == "Scissor":
        print("Rock!")
        print("You Lose")
        num = int(input("Please enter Dice(1-6): "))
        dice = randint(1,6)
        print(dice)
        if num != dice:
            play = False
            
    elif cpu == 2 and user == "Paper" :
        print("Scissor!")
        print("You Lose")
        num = int(input("Please enter Dice(1-6): "))
        dice = randint(1,6)
        print(dice)
        if num != dice:
            play = False
            
    elif cpu == 3 and user == "Rock":
        print("Paper!")
        print("You Lose")
        num = int(input("Please enter Dice(1-6): "))
        dice = randint(1,6)
        print(dice)
        if num != dice:
            play = False
    
    elif cpu == 1 and user == "Paper":
        print("Rock")
        print("You Win")
        point +=1
    elif cpu == 2 and user == "Rock":
        print("Scissor!")
        print("You Win")
        point +=1
    elif cpu == 3 and user == "Scisor":
        print("Paper!")
        print("You Win")
        point +=1
    elif user != "Rock" and user != "Scissor" and user != "Paper":
        print("Invalid Input")
    else :
        print(user+"!")
        print("Draw!")
        
print("========================")
print("END")
print("You Have:",point,"point")
# Out:
# Please Enter(Rock,Scissor,Paper): Rock
# Scissor!
# You Win
# Please Enter(Rock,Scissor,Paper): Rokc
# Invalid Input
# Please Enter(Rock,Scissor,Paper): Rokc
# Invalid Input
# Please Enter(Rock,Scissor,Paper): Rock
# Rock!
# Draw!
# Please Enter(Rock,Scissor,Paper): Rokc
# Invalid Input
# Please Enter(Rock,Scissor,Paper): Rock
# Scissor!
# You Win
# Please Enter(Rock,Scissor,Paper): Scissor
# Rock!
# You Lose
# Please enter Dice(1-6): 5
# 5
# Please Enter(Rock,Scissor,Paper): Rock
# Rock!
# Draw!
# Please Enter(Rock,Scissor,Paper): Rock
# Rock!
# Draw!
# Please Enter(Rock,Scissor,Paper): Rock
# Paper!
# You Lose
# Please enter Dice(1-6): 5
# 5
# Please Enter(Rock,Scissor,Paper): Paper
# Scissor!
# You Lose
# Please enter Dice(1-6): 5
# 4
# ...
# END
# You Have: 2 point
